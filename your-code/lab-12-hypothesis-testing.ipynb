# %% [markdown]
# # Antes de empezar:
# - Lee el archivo README.md
# - Comenta tanto como puedas y utiliza los recursos (archivo README.md)
# - ¡Feliz aprendizaje

# %%
# import numpy and pandas
import pandas as pd
import numpy as np
from scipy.stats import trim_mean, mode, skew, gaussian_kde, pearsonr, spearmanr, beta
from statsmodels.stats.weightstats import ztest as ztest

from scipy.stats import ttest_ind, norm, t
from scipy.stats import f_oneway
from scipy.stats import sem

# %% [markdown]
# # Reto 1 - Explorando los Datos
#
# En este reto, examinaremos todos los salarios de los empleados de la Ciudad de Chicago. Comenzaremos cargando el conjunto de datos y examinando su contenido.

# %%
# Run this code:
salaries = pd.read_csv(r'C:\Users\ievav\OneDrive\Documents\Ironhack\Assignments\ironhack-lab-hypothesis-testing\data\Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %% [markdown]
# Examina el conjunto de datos `salaries` utilizando la función `head` que se muestra a continuación.

# %%
salaries.head(50)
# Out:
#                         Name                                     Job Titles  \
# 0          AARON,  JEFFERY M                                       SERGEANT
# 1            AARON,  KARINA          POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2        AARON,  KIMBERLEI R                       CHIEF CONTRACT EXPEDITER
# 3        ABAD JR,  VICENTE M                              CIVIL ENGINEER IV
# 4          ABASCAL,  REECE E                    TRAFFIC CONTROL AIDE-HOURLY
# 5      ABBASI,  CHRISTOPHER                      STAFF ASST TO THE ALDERMAN
# 6      ABBATACOLA,  ROBERT J                            ELECTRICAL MECHANIC
# 7         ABBATE,  JOSEPH L                         POOL MOTOR TRUCK DRIVER
# 8      ABBATEMARCO,  JAMES J                              FIRE ENGINEER-EMT
# 9           ABBATE,  TERRY M                                 POLICE OFFICER
# 10          ABBOTT,  BETTY L                             FOSTER GRANDPARENT
# 11          ABDALLAH,  ZAID                                  POLICE OFFICER
# 12    ABDELHADI,  ABDALMAHD                                  POLICE OFFICER
# 13       ABDELLATIF,  AREF R  FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC
# 14       ABDELMAJEID,  AZIZ                                  POLICE OFFICER
# 15      ABDOLLAHZADEH,  ALI                           FIREFIGHTER/PARAMEDIC
# 16  ABDUL-KARIM,  MUHAMMAD A                      ENGINEERING TECHNICIAN VI
# 17       ABDULLAH,  DANIEL N                                FIREFIGHTER-EMT
# 18      ABDULLAH,  LAKENYA N                                 CROSSING GUARD
# 19        ABDULLAH,  RASHAD                ELECTRICAL MECHANIC (AUTOMOTIVE)
# 20     ABDULSATTAR,  MUDHAR                               CIVIL ENGINEER II
# 21     ABDUL-SHAKUR,  TAHIR                           GENERAL LABORER - DSS
# 22         ABEJERO,  JASON V                                 POLICE OFFICER
# 23   ABERCROMBIE IV,  EARL S                                  PARAMEDIC I/C
# 24    ABERCROMBIE,  TIMOTHY                              MOTOR TRUCK DRIVER
# 25        ABFALL,  RICHARD C                                 POLICE OFFICER
# 26        ABIOYE,  ADEWOLE A                     LIBRARY ASSOCIATE - HOURLY
# 27          ABNEY,  PATRICK                                  POLICE OFFICER
# 28         ABOUASSI,  CHADI                                  POLICE OFFICER
# 29    ABOUELKHEIR,  HASSAN A                      SENIOR PROGRAMMER/ANALYST
# 30        ABRAHAM,  GIRLEY T                              CIVIL ENGINEER IV
# 31         ABRAHAM,  KELVIN                        ENGINEERING TECHNICIAN V
# 32         ABRAHAM,  NANCY A                                 POLICE OFFICER
# 33    ABRAHAMSON,  MICHAEL C               STUDENT INTERN - MAYOR'S FELLOWS
# 34         ABRAM,  ANTHONY A                                 POLICE OFFICER
# 35     ABRAMAVICIUS,  ANNA A     SUPERINTENDENT OF SPECIAL TRAFFIC SERVICES
# 36       ABRAMS,  DANIELLE T                             SANITATION LABORER
# 37         ABRAMSKI,  JOHN E                            AMBULANCE COMMANDER
# 38      ABRAMSON,  NICHOLAS                                  POLICE OFFICER
# 39         ABRAMS,  SAMUEL A                        POOL MOTOR TRUCK DRIVER
# 40         ABRAMS,  TIFFANY                      OPERATING ENGINEER-GROUP C
# 41       ABRATANSKI,  MARK A                                FIREFIGHTER-EMT
# 42            ABREU,  DILAN                                SEWER BRICKLAYER
# 43         ABREU,  ROBERTO J                       TRAFFIC SIGNAL REPAIRMAN
# 44           ABREU,  ROSITA                  PERSONAL COMPUTER OPERATOR III
# 45           ABREU,  VICTOR                                 FIREFIGHTER-EMT
# 46            ABRON,  FLOYD                                  POLICE OFFICER
# 47        ABRON,  KIMYENNA D                                 POLICE OFFICER
# 48        ABRONS,  KENNETH L                            ELECTRICAL MECHANIC
# 49     ABUBAKER,  MOHAMMED G                 SENIOR ENVIRONMENTAL INSPECTOR
#
#           Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0             POLICE                 F           Salary            NaN
# 1             POLICE                 F           Salary            NaN
# 2   GENERAL SERVICES                 F           Salary            NaN
# 3        WATER MGMNT                 F           Salary            NaN
# 4               OEMC                 P           Hourly           20.0
# 5       CITY COUNCIL                 F           Salary            NaN
# 6           AVIATION                 F           Hourly           40.0
# 7      STREETS & SAN                 F           Hourly           40.0
# 8               FIRE                 F           Salary            NaN
# 9             POLICE                 F           Salary            NaN
# 10  FAMILY & SUPPORT                 P           Hourly           20.0
# 11            POLICE                 F           Salary            NaN
# 12            POLICE                 F           Salary            NaN
# 13              FIRE                 F           Salary            NaN
# 14            POLICE                 F           Salary            NaN
# 15              FIRE                 F           Salary            NaN
# 16       WATER MGMNT                 F           Salary            NaN
# 17              FIRE                 F           Salary            NaN
# 18              OEMC                 P           Hourly           20.0
# 19  GENERAL SERVICES                 F           Hourly           40.0
# 20       WATER MGMNT                 F           Salary            NaN
# 21     STREETS & SAN                 F           Hourly           40.0
# 22            POLICE                 F           Salary            NaN
# 23              FIRE                 F           Salary            NaN
# 24     STREETS & SAN                 F           Hourly           40.0
# 25            POLICE                 F           Salary            NaN
# 26    PUBLIC LIBRARY                 P           Hourly           20.0
# 27            POLICE                 F           Salary            NaN
# 28            POLICE                 F           Salary            NaN
# 29  FAMILY & SUPPORT                 F           Salary            NaN
# 30       WATER MGMNT                 F           Salary            NaN
# 31        TRANSPORTN                 F           Salary            NaN
# 32            POLICE                 F           Salary            NaN
# 33    MAYOR'S OFFICE                 F           Hourly           35.0
# 34            POLICE                 F           Salary            NaN
# 35              OEMC                 F           Salary            NaN
# 36     STREETS & SAN                 F           Hourly           40.0
# 37              FIRE                 F           Salary            NaN
# 38            POLICE                 F           Salary            NaN
# 39     STREETS & SAN                 F           Hourly           40.0
# 40       WATER MGMNT                 F           Hourly           40.0
# 41              FIRE                 F           Salary            NaN
# 42       WATER MGMNT                 F           Hourly           40.0
# 43        TRANSPORTN                 F           Salary            NaN
# 44            HEALTH                 F           Salary            NaN
# 45              FIRE                 F           Salary            NaN
# 46            POLICE                 F           Salary            NaN
# 47            POLICE                 F           Salary            NaN
# 48          AVIATION                 F           Hourly           40.0
# 49            HEALTH                 F           Salary            NaN
#
#     Annual Salary  Hourly Rate
# 0        101442.0          NaN
# 1         94122.0          NaN
# 2        101592.0          NaN
# 3        110064.0          NaN
# 4             NaN        19.86
# 5         50436.0          NaN
# 6             NaN        46.10
# 7             NaN        35.60
# 8        103350.0          NaN
# 9         93354.0          NaN
# 10            NaN         2.65
# 11        84054.0          NaN
# 12        87006.0          NaN
# 13       102228.0          NaN
# 14        84054.0          NaN
# 15        91272.0          NaN
# 16       111492.0          NaN
# 17        95484.0          NaN
# 18            NaN        17.68
# 19            NaN        46.10
# 20        65448.0          NaN
# 21            NaN        21.43
# 22        90024.0          NaN
# 23        82614.0          NaN
# 24            NaN        35.60
# 25        48078.0          NaN
# 26            NaN        25.10
# 27        76266.0          NaN
# 28        48078.0          NaN
# 29       110064.0          NaN
# 30       110064.0          NaN
# 31        55644.0          NaN
# 32        80016.0          NaN
# 33            NaN        20.00
# 34        72510.0          NaN
# 35        65820.0          NaN
# 36            NaN        36.21
# 37       128970.0          NaN
# 38        68616.0          NaN
# 39            NaN        35.60
# 40            NaN        45.07
# 41        89148.0          NaN
# 42            NaN        44.88
# 43       101712.0          NaN
# 44        70092.0          NaN
# 45        99324.0          NaN
# 46        90024.0          NaN
# 47        48078.0          NaN
# 48            NaN        46.10
# 49        84420.0          NaN

# %% [markdown]
# # Reto 2 - Pruebas de Hipótesis
#
# En esta sección del laboratorio, vamos a probar si el salario por hora de todos los trabajadores por hora es significativamente diferente de $30/hora. Importa la función correcta para la prueba de una muestra desde scipy y realiza la prueba de hipótesis para un intervalo de confianza de dos lados del 95%.

# %%
from scipy.stats import ttest_1samp

hourly_salaries = salaries[salaries['Hourly Rate'].notna()]
hourly_salaries.head()

t_statistic, p_value = ttest_1samp(hourly_salaries['Hourly Rate'], 30)

print(f"T-statistic: {t_statistic}")
print(f"P-value: {p_value}")

alpha = 0.05  
if p_value < alpha:
    print("Reject the null hypothesis: The average hourly salary is significantly different from $30.")
else:
    print("Fail to reject the null hypothesis: The average hourly salary is not significantly different from $30.")
# Out:
# T-statistic: 20.6198057854942
# P-value: 4.3230240486229894e-92
# Reject the null hypothesis: The average hourly salary is significantly different from $30.

# %% [markdown]
# # Reto 3 - Construyendo Intervalos de Confianza
#
# Aunque probar nuestra hipótesis es una excelente manera de obtener evidencia empírica para aceptar o rechazar la hipótesis, otra forma de recopilar evidencia es creando un intervalo de confianza. Un intervalo de confianza nos brinda información sobre la media verdadera de la población. Por lo tanto, para un intervalo de confianza del 95%, estamos seguros en un 95% de que la media de la población se encuentra dentro del intervalo de confianza.
#
# Para leer más sobre los intervalos de confianza, haz clic [aquí](https://es.wikipedia.org/wiki/Intervalo_de_confianza).
#
# En la celda a continuación, construiremos un intervalo de confianza del 95% para el salario por hora medio de todos los trabajadores por hora.
#
# El intervalo de confianza se calcula en SciPy utilizando la función `t.interval`. Puedes leer más sobre esta función [aquí](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# Para calcular el intervalo de confianza del salario por hora, usa 0.95 para el nivel de confianza, el número de filas - 1 para los grados de libertad, la media de la muestra para el parámetro de ubicación y el error estándar para la escala. El error estándar se puede calcular utilizando [esta](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) función en SciPy.

# %%
from scipy import stats

# %%
mean_salary = hourly_salaries['Hourly Rate'].mean()
sem_salary = stats.sem(hourly_salaries['Hourly Rate'])

# Degrees of freedom
df = len(hourly_salaries) - 1

# Confidence level
confidence_level = 0.95

# Calculate the confidence interval
confidence_interval = stats.t.interval(confidence_level, df, loc=mean_salary, scale=sem_salary)

# Display the confidence interval
print(f"95% Confidence Interval: {confidence_interval}")
# Out:
# 95% Confidence Interval: (32.52345834488425, 33.05365708767623)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(hourly_salaries['Hourly Rate'], bins=30, color='teal', edgecolor='black')
plt.title('Histogram of Hourly Salaries')
plt.xlabel('Hourly Rate')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# # Reto 4 - Pruebas de Hipótesis de Proporciones
#
# Otro tipo de prueba de una muestra es una prueba de hipótesis de proporciones. En esta prueba, examinamos si la proporción de un grupo en nuestra muestra es significativamente diferente de una fracción.
#
# Puedes leer más sobre las pruebas de proporción de una muestra [aquí](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# En la celda a continuación, utiliza la función `proportions_ztest` de `statsmodels` para realizar una prueba de hipótesis que determinará si el número de trabajadores por hora en la Ciudad de Chicago es significativamente diferente del 25% en el nivel de confianza del 95%.

# %%
from statsmodels.stats.proportion import proportions_ztest, proportion_confint

hourly = len(hourly_salaries)
not_hourly = len(salaries)       
value = 0.2  # hypothesized proportion

# Perform the two-sided z-test for proportions
stat, p_value = proportions_ztest(hourly, not_hourly, value=value, alternative='two-sided')

# Calculate the 95% confidence interval for the proportion of hourly workers
confint_low, confint_high = proportion_confint(hourly, not_hourly, alpha=0.05, method='normal')

# Display the result
print(f"Z-statistic: {stat}")
print(f"P-value: {p_value}")
print(f"95% Confidence Interval: ({confint_low:.4f}, {confint_high:.4f})")
# Out:
# Z-statistic: -3.5099964213703005
# P-value: 0.0004481127249057967
# 95% Confidence Interval: (0.2371, 0.2464)
